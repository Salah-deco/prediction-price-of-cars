# %%
import pandas as pd
import numpy as np
import time
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
import pickle

# %%
df = pd.read_csv('data4x4.csv')

# %%
df = data

# %%
encoder_location = LabelEncoder()
df['Location'] = encoder_location.fit_transform(df['Location'])

all_locations = encoder_location.classes_
locations = dict()

for l in all_locations:
    locations[l] = encoder_location.transform([l])[0]

# %%
encoder_model= LabelEncoder()
df['Model'] = encoder_model.fit_transform(df['Model'])

all_model = encoder_model.classes_
models = dict()

for l in all_model:
    models[l] = encoder_model.transform([l])[0]

# %%
encoder_brand= LabelEncoder()
df['Brand'] = encoder_brand.fit_transform(df['Brand'])

all_brand = encoder_brand.classes_
brands = dict()

for l in all_brand:
    brands[l] = encoder_brand.transform([l])[0]

# %%
encoder_origine = LabelEncoder()
df['Origine'] = encoder_origine.fit_transform(df['Origine'])

all_origine = encoder_origine.classes_
origines = dict()

for l in all_origine:
    origines[l] = encoder_origine.transform([l])[0]

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['Price', 'Mileage'], axis=1), df.Price, test_size = 0.14, random_state = 25)
rf1 = RandomForestRegressor()
rf1.fit(X_train, y_train)
y_pred= rf1.predict(X_test)
print("Accuracy on Traing set: ",rf1.score(X_train,y_train))
print("Accuracy on Testing set: ",rf1.score(X_test,y_test))
# Out:
# Accuracy on Traing set:  0.9850791080491905
# Accuracy on Testing set:  0.8869048328777724

# %%
print('Mean Absolute Error      : ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared  Error      : ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared  Error : ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R Squared Error          : ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error      :  11550.574035533165
# Mean Squared  Error      :  591012324.0760298
# Root Mean Squared  Error :  24310.745033339266
# R Squared Error          :  0.8869048328777724

# %%
data = pd.read_csv("dataF 5 acc88.csv")

# %%
data.head(5)
# Out:
#       Price    Location  Fuel type  Fiscal power  Boite à vitesse    Brand  \
# 0   31000.0        Salé          0             6                0  Renault
# 1   50000.0        Salé          0            11                0  Renault
# 2   55000.0        Salé          0             8                0  Renault
# 3   26000.0  Oued Amlil          1             6                0  Peugeot
# 4  175000.0   Marrakech          1             8                1    Skoda
#
#      Model  Model Year            Mileage  Nombre de portes      Origine  \
# 0     Clio        1992  150 000 - 159 999                 5    Dédouanée
# 1   Laguna        2009  110 000 - 119 999                 5  WW au Maroc
# 2   Megane        2008          0 - 4 999                 5  WW au Maroc
# 3      205        1984    75 000 - 79 999                 5    Dédouanée
# 4  Octavia        2016  150 000 - 159 999                 5  WW au Maroc
#
#    Première main  minMileage  maxMileage  4x4
# ...

# %%
data.loc[0].Model
# Out:
# 'Clio'

# %%
len(df.Model.unique())
# Out:
# 624

# %%
data['4x4'] = 0

# %%
listOf4x4 = list()

# %%
def is4x4(i):
    data.iloc[i,-1] = 1

# %%
def check(i):
    ligne = data.loc[i]
    if ligne.Model in list4x4:
        is4x4(i)

# %%
def addToListOf4x4():
    for br in data.Brand.unique():
        print("Brand :", br)
        for ml in data[data.Brand == br].Model.unique():
            print("\tModel :", ml)
            ch = input("is a 4x4 ? ")
            if ch == 'y':
                listOf4x4.append((br, ml))
    print()

# %%
addToListOf4x4()
# Out:
# Brand : Renault
# 	Model : Clio
# is a 4x4 ?
# 	Model : Laguna
# is a 4x4 ?
# 	Model : Megane
# is a 4x4 ?
# 	Model : 19
# is a 4x4 ?
# 	Model : R19
# is a 4x4 ?
# 	Model : Kangoo
# is a 4x4 ?
# 	Model : R9
# is a 4x4 ?
# 	Model : Scenic
# is a 4x4 ?
# 	Model : R25
# is a 4x4 ?
# 	Model : Fluence
# is a 4x4 ?
# 	Model : Captur
# is a 4x4 ?
# 	Model : Megane 3
# is a 4x4 ?
# 	Model : Super 5
# is a 4x4 ?
# 	Model : Trafic
# is a 4x4 ?
# 	Model : Symbol
# is a 4x4 ?
# 	Model : Express
# is a 4x4 ?
# 	Model : Megane Coupe
# is a 4x4 ?
# 	Model : Espace
# is a 4x4 ?
# 	Model : Latitude
# is a 4x4 ?
# 	Model : R21
# is a 4x4 ?
# 	Model : R5
# is a 4x4 ?
# 	Model : R4
# is a 4x4 ?
# 	Model : Laguna Coupe
# is a 4x4 ?
# 	Model : Megane CC
# is a 4x4 ?
# 	Model : Koleos
# is a 4x4 ?
# 	Model : 12
# is a 4x4 ?
# 	Model : Talisman
# is a 4x4 ?
# 	Model : Twingo
# is a 4x4 ?
# 	Model : R11
# is a 4x4 ?
# 	Model : R18
# is a 4x4 ?
# 	Model : Kangoo Express
# is a 4x4 ?
# 	Model : Grand Espace
# ...

# %%
data[data.Brand == 'Dacia'].Model.unique()
# Out:
# array(['Duster', 'Sandero', 'Logan', 'Dokker', 'Dokker Van', 'Logan Mcv',
#        'Lodgy'], dtype=object)

# %%
listOf4x4
# Out:
# [('Skoda', 'Kodiaq'),
#  ('Ford', 'Kuga'),
#  ('Ford', 'Ranger'),
#  ('Ford', 'EXPLORER'),
#  ('Ford', 'F150'),
#  ('Fiat', 'FREEMONT'),
#  ('Toyota', 'Prado'),
#  ('Toyota', 'Land Cruiser'),
#  ('Toyota', 'Hilux'),
#  ('Toyota', 'RAV 4'),
#  ('Toyota', '4RUNNER'),
#  ('Mercedes-Benz', 'CLASSE ML'),
#  ('Mercedes-Benz', 'Classe G'),
#  ('Mercedes-Benz', 'Classe GLE'),
#  ('Mercedes-Benz', 'Classe M'),
#  ('Mercedes-Benz', 'Classe GLC'),
#  ('Mercedes-Benz', 'CLASSE GLK'),
#  ('Mercedes-Benz', 'Classe GL'),
#  ('Mercedes-Benz', 'Classe GLS'),
#  ('Volkswagen', 'Touareg'),
#  ('Volkswagen', 'Amarok'),
#  ('Audi', 'Q7'),
#  ('Audi', 'Q5'),
#  ('Audi', 'S5'),
#  ('Audi', 'RS3'),
#  ('Audi', 'Q2'),
#  ('Audi', 'S3'),
#  ('Hyundai', 'Santa Fe'),
#  ('Hyundai', 'IX55'),
#  ('Hyundai', 'ix 35'),
#  ('Hyundai', 'Tucson'),
#  ('Hyundai', 'Veracruz'),
#  ('Hyundai', 'CRETA'),
#  ('Hyundai', 'GALLOPER'),
#  ('Hyundai', 'TERRACAN'),
#  ('Suzuki', 'Grand Vitara'),
#  ('Opel', 'MOKKA'),
# ...

# %%
listOf4x4.append(('Audi', 'Q3'))

# %%
data[data.Model =='X3']
# Out:
#           Price    Location  Fuel type  Fiscal power  Boite à vitesse Brand  \
# 1509   240000.0     Kénitra          1             8                0   BMW
# 1586   232000.0  Casablanca          1             8                0   BMW
# 1871   295000.0  Casablanca          1             8                1   BMW
# 2069   389000.0  Casablanca          1            12                1   BMW
# 2132   389000.0  Casablanca          1            12                1   BMW
# 3380   120000.0         Fès          1             8                0   BMW
# 3382    85000.0  Casablanca          0            11                0   BMW
# 5083   260000.0      Tanger          1             8                1   BMW
# 5721   285000.0  Casablanca          1             8                1   BMW
# 7552   155000.0      Tanger          1             8                1   BMW
# 7594   188000.0  Casablanca          1             8                1   BMW
# ...

# %%
for i in range(0,29346):
    check(i)

# %%
listOf4x4
# Out:
# [('Skoda', 'Kodiaq'),
#  ('Ford', 'Kuga'),
#  ('Ford', 'Ranger'),
#  ('Ford', 'EXPLORER'),
#  ('Ford', 'F150'),
#  ('Fiat', 'FREEMONT'),
#  ('Toyota', 'Prado'),
#  ('Toyota', 'Land Cruiser'),
#  ('Toyota', 'Hilux'),
#  ('Toyota', 'RAV 4'),
#  ('Toyota', '4RUNNER'),
#  ('Mercedes-Benz', 'CLASSE ML'),
#  ('Mercedes-Benz', 'Classe G'),
#  ('Mercedes-Benz', 'Classe GLE'),
#  ('Mercedes-Benz', 'Classe M'),
#  ('Mercedes-Benz', 'Classe GLC'),
#  ('Mercedes-Benz', 'CLASSE GLK'),
#  ('Mercedes-Benz', 'Classe GL'),
#  ('Mercedes-Benz', 'Classe GLS'),
#  ('Volkswagen', 'Touareg'),
#  ('Volkswagen', 'Amarok'),
#  ('Audi', 'Q7'),
#  ('Audi', 'Q5'),
#  ('Audi', 'S5'),
#  ('Audi', 'RS3'),
#  ('Audi', 'Q2'),
#  ('Audi', 'S3'),
#  ('Hyundai', 'Santa Fe'),
#  ('Hyundai', 'IX55'),
#  ('Hyundai', 'ix 35'),
#  ('Hyundai', 'Tucson'),
#  ('Hyundai', 'Veracruz'),
#  ('Hyundai', 'CRETA'),
#  ('Hyundai', 'GALLOPER'),
#  ('Hyundai', 'TERRACAN'),
#  ('Suzuki', 'Grand Vitara'),
#  ('Opel', 'MOKKA'),
# ...

# %%
list4x4=list()

# %%
for e in listOf4x4:
    list4x4.append(e[1])

# %%
list4x4
# Out:
# ['Kodiaq',
#  'Kuga',
#  'Ranger',
#  'EXPLORER',
#  'F150',
#  'FREEMONT',
#  'Prado',
#  'Land Cruiser',
#  'Hilux',
#  'RAV 4',
#  '4RUNNER',
#  'CLASSE ML',
#  'Classe G',
#  'Classe GLE',
#  'Classe M',
#  'Classe GLC',
#  'CLASSE GLK',
#  'Classe GL',
#  'Classe GLS',
#  'Touareg',
#  'Amarok',
#  'Q7',
#  'Q5',
#  'S5',
#  'RS3',
#  'Q2',
#  'S3',
#  'Santa Fe',
#  'IX55',
#  'ix 35',
#  'Tucson',
#  'Veracruz',
#  'CRETA',
#  'GALLOPER',
#  'TERRACAN',
#  'Grand Vitara',
#  'MOKKA',
#  'Grandland X',
#  'ANTARA',
#  'FRONTERA',
#  'CAMPO',
#  'Qashqai',
#  'X-Trail',
#  'Juke',
#  'Murano',
#  'Navara',
#  'Pathfinder',
#  'PATROL',
#  'Pick up',
#  'TERRANO',
#  'GTR',
#  'Patrol GR',
#  'DS7',
#  'XC60',
#  'XC90',
#  'XC70',
#  'Sportage',
#  'Sorento',
#  'Seltos',
#  'CARNIVAL',
#  'X5',
#  'X3',
#  'X1',
#  'X6',
#  'Range Rover Sport',
#  'Freelander',
#  'Range Rover Evoque',
#  'Range Rover',
#  'Defender',
#  'Discovery',
#  'Velar',
#  'Discovery Sport',
# ...

# %%
data.to_csv('data4x4.csv', index=False, encoding='utf-8-sig')
